# %% [markdown]
# # Object Oriented Programming (OOP)
#
# OOP (Object-Oriented Programming) is a programming style where we organize code using classes and objects instead of writing everything in separate functions.
#
# OR:
#
# Object Oriented Programming (OOP) is a programming paradigm.
# - It uses "objects" to represent data and methods to manipulate that data.
# - It helps in organizing code, making it reusable, and easier to maintain.
# - OOP is based on four main principles: Encapsulation, Abstraction, Inheritance, and Polymorphism.

# %% [markdown]
# ## Classes and Objects
#
# - A class is a blueprint for creating objects. It defines attributes (data) and methods (functions) that the objects created from the class will have.
#
# - An object is an instance of a class. It contains data and can perform actions defined by the class.
#
# Simple Definition: An object is an actual thing created from a class.
#
# In Python, you can define a class using the `class` keyword. Here's an example:
#
# ```python
# class ClassName:
#     # Constructor method to initialize attributes
#     def __init__(self, attribute1, attribute2):
#         self.attribute1 = attribute1  # Attribute
#         self.attribute2 = attribute2    # Attribute
#
#     # Method of the class (functions inside a class are called methods)
#     def method1(self):
#       pass
#
#     def method2(self, param):
#         pass
# ```

# %%
class Person:
    # properties/data => attributes
    def __init__(self,name, age): # Constructor
        self.name = name
        self.age = age
        print(f"Name: {self.name} , Age: {self.age}")
        # other attributes

    # behaviour/functions => methods
    def walk(self):
        print(f"{self.name} is walking")
        print(self)

    # other behaviours

# %%
name = "Hamad"
age = 24
person1 = Person(name, age)
# Out:
# Name: Hamad , Age: 24

# %%
person1.walk()
# Out:
# Hamad is walking
# <__main__.Person object at 0x0000027555F6E120>

# %%
print(person1.name , age)
# Out:
# Hamad 24

# %% [markdown]
# ## Instance Variables and
#
# Instance Variable: An instance variable is a variable that belongs to an object. Each object has its own copy.
#
# Instance Method: An instance method is a function inside a class that works with an object. It always has self as its first parameter.
#
# OR:
#
# - Instance variables are attributes that belong to an instance (object) of a class.
# - They are defined in the constructor method `__init__`.
# - Instance methods are functions that operate on the instance of the class.
# - They can access and modify instance variables.
#
# Here's an example of a class with instance variables and methods:
#
# ```python
# class BankAccount:
#     def __init__(self, account_holder, balance=0):
#         self.account_holder = account_holder  # Instance variable
#         self.balance = balance  # Instance variable
#
#     def deposit(self, amount):  # Instance method
#         pass
#
#     def withdraw(self, amount):  # Instance method
#         pass
#
#     def get_balance(self):  # Instance method
#         pass
# ```

# %%
class BankAccount:
    def __init__(self, account_holder, balance=0):
        self.account_holder = account_holder
        self.balance = balance
        
    def deposit(self, amount):
        self.balance += amount
        
    def withdraw(self, amount):
        if self.balance < amount:
            print("Not enough blance")
            return
        self.balance -= amount
    
    def get_balance(self):
        print(f"You current account balance is {self.balance}")
    
    def check_self(self):
        print(self)

# %%
my_account = BankAccount(account_holder="Hamad", balance=10000)
my_account.account_holder
# Out:
# 'Hamad'

# %%
my_account.deposit(5000)
my_account.get_balance()
# Out:
# You current account balance is 15000

# %%
my_account.withdraw(15000)
my_account.get_balance()
# Out:
# You current account balance is 0

# %%
my_account.withdraw(20000)
# Out:
# Not enough blance

# %%
print(my_account)
# Out:
# <__main__.BankAccount object at 0x0000027555D8AE90>

# %%
my_account.check_self()
# Out:
# <__main__.BankAccount object at 0x0000027555D8AE90>

# %% [markdown]
# ## Class Variables and Functions
#
# Class Variable: A class variable is a variable that belongs to the class, not to individual objects. It is shared by all objects of that class.
#
# Class Method (Function): A class method is a method that works with the class instead of a specific object. It uses cls as its first parameter and is decorated with @classmethod.
#
# OR:
#
# - Class variables are shared among all instances of a class.
# - They are defined within the class but outside any methods.
# - Class methods are methods that operate on the class itself rather than on instances of the class.
# - They are defined using the `@classmethod` decorator and take `cls` as the first parameter.
#
# Here's an example of a class with class variables and class methods:
#
# ```python
# class ClassName:
#     class_var = None  # Class variable
#
#     def __init__(self, params):
#         # Attributes or instance variables
#         pass
#
#
#     @classmethod
#     def class_method(cls):  # Class functions
#         pass
# ```

# %%
class Player:
    player_count = 0

    def __init__(self, name):
        self.name = name
        Player.player_count += 1

    @classmethod
    def show_player_count(cls):
        print(cls.player_count)

# %%
player1 = Player("Hamad")

# %%
player1.player_count
# Out:
# 1

# %%
player2 = Player("Naveed")
player3 = Player("Hamza")

# %%
Player.player_count
# Out:
# 3

# %%
Player.show_player_count()
# Out:
# 3

# %% [markdown]
# # Inheritance
#
# Inheritance is a feature in OOP where one class inherits (gets) the attributes and methods of another class.
#
# Simple Definition: Inheritance allows one class to reuse the properties and methods of another class.
#
# OR:
#
# Inheritance is a mechanism in OOP that allows a new class (child class) to inherit attributes and methods from an existing class (parent class).
# - This promotes code reusability and establishes a hierarchical relationship between classes.
# - The child class can have its own attributes and methods in addition to those inherited from the parent class.
#
# In Python, inheritance is implemented as follows:
#
# ```python
# class ParentClass:
#     def __init__(self, parent_attr):
#         self.parent_attr = parent_attr
#         print("parent class constructor called")
#
#     def parent_method(self):
#         pass
#
# class ChildClass(ParentClass):  # Inheriting from ParentClass
#     def __init__(self, parent_attr, child_attr):
#         super().__init__(parent_attr)  # Call the constructor of the parent class
#         print("child class constructor called")
#         self.child_attr = child_attr
#
#     def child_method(self):
#         pass
# ```

# %%
class Vehicle: # Parent Class
    def __init__(self, vehicle_type):
        self.vehicle_type = vehicle_type

    def start(self):
        print("Engine started...")

class Car(Vehicle): # Child Class
    pass

car1 = Car("Car")
car1.start()
# Out:
# Engine started...

# %%
class Vehicle:
    def __init__(self, vechicle_type):
        self.vehicle_type = vechicle_type

    def start(self):
        print("Engine started...")

# %%
vehicle = Vehicle("Bus")
vehicle.start()
# Out:
# Engine started...

# %%
print(vehicle.vehicle_type)
# Out:
# Bus

# %%
class Truck(Vehicle):
    def __init__(self, vehicle_type, make, model, year):
        super().__init__(vehicle_type)
        self.make = make
        self.model = model
        self.year = year
        
    def change_transmission_model(self, mode):
        print(f"Transmission switched to {mode}")

    # Overriding super().start() method
    def start(self):
        super().start()
        print("Truck engine started")

# %%
info = Truck("Truck", "Royal", "xyz", 2026)
info

# %%
print(info.make)
# Out:
# Royal

# %%
print(info.model)
# Out:
# xyz

# %%
print(info.year)
# Out:
# 2026

# %%
info.start()
# Out:
# Engine started...
# Truck engine started

# %%
info.change_transmission_model("auto")
# Out:
# Transmission switched to auto

# %%
vehicle.start()
# Out:
# Engine started...

# %% [markdown]
# ## Abstract Classes and Methods
# - An abstract class is a class that cannot be instantiated on its own and is meant to be subclassed.
# - It can contain abstract methods, which are methods that are declared but contain no implementation.
# - Abstract classes are used to define a common interface for a group of related classes.
#
# OR:
#
# An abstract class is a class that cannot be used to create objects. It is only used as a base (parent) class for other classes.
#
# Simple Definition: An abstract class is a blueprint that other classes must inherit from.
#
# An abstract method is a method that is declared but has no implementation in the abstract class. Every child class must implement it.
#
# Simple Definition: An abstract method is a method that the child class must define.
#
# In Python, you can create abstract classes and methods using the `abc` module:
#
# ```python
# from abc import ABC, abstractmethod
#
# class AbstractClass(ABC):
#     @abstractmethod
#     def abstract_method(self):
#         pass
#
# class ConcreteClass(AbstractClass):
#     def abstract_method(self):
#         print("Implementation of abstract method")

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod # decorator
    def area(self):
        pass

class Rectangle(Shape):
    def area(self):
        print("Area of Rectangle")

# %%
rectangle = Rectangle()
rectangle.area()
# Out:
# Area of Rectangle

# %%
print(Shape)
# Out:
# <class '__main__.Shape'>

# %%
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    
    def get_radius(self):
        return self.radius

    def area(self):
        return 3.14 * self.radius**2

# %%
circle = Circle(2)

# %%
circle.area()
# Out:
# 12.56

# %% [markdown]
# ## Dunder Methods/Magic Functions
#
# Dunder methods are special methods in Python whose names start and end with double underscores (__).
#
# Simple Definition: Dunder methods are special methods that Python calls automatically.
#
# OR:
#
# Dunder methods (short for "double underscore" methods) are special methods in Python that have double underscores at the beginning and end of their names (e.g., `__init__`, `__str__`, `__repr__`, etc.).
# - They are used to define the behavior of objects for built-in operations and functions.
# - For example, the `__init__` method is called when an object is created, and the `__str__` method defines how an object is represented as a string.

# %%
class ComplexNumber:
    def __init__(self, real, imag):
        self.real = real
        self.imag = imag

    def __str__(self):
        return f"{self.real} + {self.imag}i"

    def __repr__(self):
        return f"{self.real} + {self.imag}i"
    
    def __eq__(self, c):
        if self.real == c.real and self.imag == c.imag:
            return True
        else:
            return False

    def __add__(self, c):
        real = self.real + c.real
        imag = self.imag + c.imag
        
        return ComplexNumber(real, imag)

# %%
c1 = ComplexNumber(2, 3)
print(c1)
# Out:
# 2 + 3i

# %%
str(c1)
# Out:
# '2 + 3i'

# %%
c2 = ComplexNumber(2, 4)
print(c2)
# Out:
# 2 + 4i

# %%
c1 == c2
# Out:
# False

# %%
c3 = ComplexNumber(2, 4)
c2 == c3
print(c2 + c3)
# Out:
# 4 + 8i

# %%
#___________________________________________END_____________________________________________________________
