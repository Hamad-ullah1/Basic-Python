# %% [markdown]
# # Functions:
# - A function is a block of reusable code that performs a specific task.
# - Functions help in organizing code, improving readability, and avoiding repetition.
# - Functions can take inputs (parameters) and return outputs (results).
# The syntax for defining a function in Python is as follows:
# ```python
# def function_name(parameters):
#     # Function body
#     # Code to be executed
#     return result  # Optional

# %%
def avg(listt):
    summ = 0
    for i in range(len(listt)):
        summ = summ + listt[i]
    
    return summ / len(listt)

# %%
marks = [30,49,60,85]

avg_marks = avg(marks)
print(f"Average marks: {avg_marks}")

# ......
# ......
# ......
# ......
# ......
# ......

salaries = [1000,50000,200000,400000]
avg_salary = avg(salaries)
print(f"Average salary: {avg_salary}")
# ......
# ......
# ......
# ......
# ......
# ......
# ......
# ......
# ......
# ......
# ......
# ......

heights = [3, 4, 5, 6]
avg_heights = avg(heights)
print(f"Average height: {avg_heights}")
# Out:
# Average marks: 56.0
# Average salary: 162750.0
# Average height: 4.5

# %%
def greet():
    # statements
    print("Hello Ahmad, Welcome")

# %%
greet()
# Out:
# Hello Ahmad, Welcome

# %%
greet
# Out:
# <function __main__.greet()>

# %%
def greet(name): # parameters
    print(f"Hello {name}, Welcome")
greet(name="Ahmad") # arguments
# Out:
# Hello Ahmad, Welcome

# %%
#Take input from user
name = input("Enter your name: ")
greet(name=name)
# Out:
# Hello Hamad, Welcome

# %% [markdown]
# ## Parameters and Arguments
# - Parameters are placeholders for values that a function can accept.
# - Arguments are the actual values passed to the function when it is called.

# %%
# Function can take input (parameters)
def greet(name): # name is parameter
  print(f"Hello {name}, Welcome to class")

# %%
greet("Hamad")
# Out:
# Hello Hamad, Welcome to class

# %%
def add(x, y):
    summ = x + y
    return summ

# %%
addd = add(12, 30) # return value
addd
# Out:
# 42

# %%
num1 = 13
num2 = 14

# Arguments are values passed to the function when calling it
summ = add(num1, num2)
summ
# Out:
# 27

# %%
# functions can return multiple values
def sum_and_prod(x, y, z):
  print(f"x = {x}, y = {y}, z = {z}")
  summ = x + y + z
  prod = x * y * z
  
  return summ, prod

# %%
abc = sum_and_prod(2, 4, 6)
abc
# Out:
# x = 2, y = 4, z = 6
# (12, 48)

# %%
a,b  = (12, 48)

# %%
type(abc)
# Out:
# tuple

# %% [markdown]
# ## Variables and Scope
#
# - Variables defined inside a function are local to that function and cannot be accessed outside.
# - Variables defined outside a function are global and can be accessed inside the function.
#
# - Scope refers to the visibility and accessibility of variables in different parts of the code.
#
# # Types of Variable
#
# 1. Global Scope
#
# A variable created outside any function is called a global variable.
#
# It can be used inside and outside functions (as long as you don't overwrite it).
# - Variables defined outside a function are global and can be accessed inside the function.
#
# 2. Local Scope
#
# A variable created inside a function is called a local variable.
#
# It can only be used inside that function.

# %%
# Scope of variables
def func():
  c = 2 # local variable
  print(c)

  # global variable
c = 13
func()
print(c)  # prints 20
# Out:
# 2
# 13

# %%
c = 13  # global variable
print(f"outside func2: {c}")
c = 20

def func2():
    global d
    d = 34
    print(f"inside func2: {d}")

func2()

print(d)
# Out:
# outside func2: 13
# inside func2: 34
# 34

# %%
abc = 8
print(f"outside my_function: {abc}")


def my_function():
    abc = 7
    print(f"inside my_function: {abc}")

my_function()
# Out:
# outside my_function: 8
# inside my_function: 7

# %% [markdown]
# ## Default, Positional, and Keyword Arguments
# - A default argument means "The parameter already has a value. If you don't pass an argument, Python uses the default value".
#
# - A positional argument means "The values are matched to the parameters based on their position (order)".
#
# - Keyword arA keyword argument means "You specify the parameter name when passing the value".

# %%
def greet(name, age):
    print(f'Hello {name}, Welcome! You are {age} old.')

greet("Hamad", 24)
greet(age = 21, name = 'kamran')
# Out:
# Hello Hamad, Welcome! You are 24 old.
# Hello kamran, Welcome! You are 21 old.

# %%
# keyword arguments can be used to call functions
# This allows passing arguments in any order
def sum_and_prod(w, x, y, z):
    print(f"w = {w}, x = {x}, y = {y}, z = {z}")
    return w+x+y+z, w*x*y*z

# %%
sum_and_prod(1, 3, 7, 5) # Passing arguments as positional args
# Out:
# w = 1, x = 3, y = 7, z = 5
# (16, 105)

# %%
sum_and_prod(z = 10,w = 19, x = 24, y = 50) # Keyword arguments
# Out:
# w = 19, x = 24, y = 50, z = 10
# (103, 228000)

# %%
sum_and_prod(y=1, x=2, z=3, w=4)
# Out:
# w = 4, x = 2, y = 1, z = 3
# (10, 24)

# %%
def sum_and_prod(w=0, x=0, y=0, z=0):

    print(f"w = {w}, x = {x}, y = {y}, z = {z}")

    return w + x + y + z, w * x * y * z


sum_and_prod(5, z=12) # Passing positional and keyword arguments
# Out:
# w = 5, x = 0, y = 0, z = 12
# (17, 0)

# %%
# default arguments
def add(x=0, y=0, z=0):
    print(f"x = {x}, y = {y}, z={z}")
    summ = x + y + z
    return summ

# %%
# passing arguments as positional args
add(2, 1, 3)
# Out:
# x = 2, y = 1, z=3
# 6

# %%
# passign args as keyword args
add(y=10, x=0, z=1)
# Out:
# x = 0, y = 10, z=1
# 11

# %%
add(z=10) # you can skip default arguments
print('Hamad')
print('Khan')
# Out:
# x = 0, y = 0, z=10
# Hamad
# Khan

# %% [markdown]
# ## lambda
#
# A lambda function is a small, anonymous (nameless) function.
#
# It is used when you need a function only once.
#
# It is defined by using the `lambda` keyword.
#
# Easy Definition:
# A lambda is a short way of writing a simple function in one line
#
# Syntax :
# lambda arguments: expression

# %%
def square(x):
  # statement 1
  # stateme 2
  return x ** 2

square(3)
# Out:
# 9

# %%
lambda_square = lambda x: x ** 2

# %%
lambda_square(3)
# Out:
# 9

# %% [markdown]
# # Higher-Order Function
#
# - A Higher-Order Function is a function that takes another function as an argument, or
# Returns another function.
#
# - Common higher-order functions in Python include `map()`, `filter()`, and `reduce()`.

# %%
def add_one(x):
  return x + 1

def add_two(x):
  return x + 2

def increment(x, adder): # higher order function
  inc_x = adder(x)
  return inc_x

# %%
increment(10, add_one)
# Out:
# 11

# %%
print(add_one)
# Out:
# <function add_one at 0x000001D2E30D2980>

# %%
# map() applies a function to all items in an input list and returns 
# a new list with the results.
numbers = list(range(0, 30, 3))
numbers
# Out:
# [0, 3, 6, 9, 12, 15, 18, 21, 24, 27]

# %%
list(map(lambda x: x+1, numbers))
# Out:
# [1, 4, 7, 10, 13, 16, 19, 22, 25, 28]

# %%
def my_filter(x):
  return x > 14

# %%
# filter() creates a list of elements for which a function returns true.
list(filter(lambda x: x > 14, numbers))
# Out:
# [15, 18, 21, 24, 27]

# %%
import random

# %%
from functools import reduce
numbers = list(map(lambda x: x+1, numbers))

reduce(lambda x, y: x+y, numbers)
# Out:
# 145

# %% [markdown]
# # Errors and Exceptions
# - Errors are issues in the code that prevent it from running correctly.
#   - Syntax errors occur when the code does not follow the correct syntax rules.
#   - Runtime errors occur during the execution of the code.
#   - Logical errors occur when the code runs but produces incorrect results.
# - Exceptions are specific types of errors that can be handled using try-except blocks.

# %%
# Errors and Exceptions example
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

summ = num1 + num2
print(f"Sum: {summ}")

diff = num1 - num2
print(f"Difference: {diff}")

prod = num1 * num2
print(f"Product: {prod}")

quot = num1 / num2 # Careful, problematic, try entering 0 for second number
print(f"Quotient: {quot}")
# Out:
# Sum: 25.0
# Difference: -1.0
# Product: 156.0
# Quotient: 0.9230769230769231

# %% [markdown]
# # Exception Handling
# - Exception handling allows you to manage errors gracefully without crashing the program.
# The syntax for handling exceptions in Python is as follows:
# ```python
# try:
#     # Code that may raise an exception
# except ExceptionType: # Can be multiple except blocks for different exceptions
#     # Code to handle the exception
# finally:
#     # Optional code that runs regardless of whether an exception occurred

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

summ = num1 + num2
print(f"Sum: {summ}")

diff = num1 - num2
print(f"Difference: {diff}")

prod = num1 * num2
print(f"Product: {prod}")

# quot = num1 / num2  # Since division by zero can raise an exception, we will handle it

try:
    quot = num1 / num2
except ZeroDivisionError:
    quot = None
    print("Error: Division by zero is not allowed.")


print(f"Quotient: {quot}")
# Out:
# Sum: 36.0
# Difference: -12.0
# Product: 288.0
# Quotient: 0.5

# %%
# You can check for multiple exceptions
try:
  quot = num1 / num2
except ZeroDivisionError:
  quot = None
  print("Error: Division by zero is not allowed.")
except Exception as e:
  print(e)
  print("Something went wrong!")

# %%
# Error handling can optionally include else block, which is executed
# when no error occurs in try block
try:
    quot = num1 / num2
except ZeroDivisionError:
    quot = None
    print("Error: Division by zero is not allowed.")
except Exception as e:
    print(e)
else: # this block is executed when no error occurs in try block
  print("No error occurred")
# Out:
# No error occurred

# %%
# Error handling can optionally include finally block, which is
# always executed at the end. It doesn't matter whether error occurs
# or not in the try block. Usually used for releasing resources

try:
  file = open("example.txt", "w") # open a file for writing
  file.write("Hello World!\n")
  result = num1 / num2  # error can occur if num2 is zero
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
finally:
    file.close()
    print("File closed. This block is always executed, releasing resources if needed.")
# Out:
# File closed. This block is always executed, releasing resources if needed.

# %% [markdown]
# # Practice Tasks:
#  - Write a function `calculate_percentage(obtained, total)`
#  - Write a function `calculate_salary(hours, rate)`
#  - Write a function `calculate_bill(price, quantity)` that returns total cost.
#  - Write a function `is_vowel(char)` that returns True or False
#  - Write a function `count_digits(num)` that returns how many digits are in a number.
#  - Write a function `reverse_number(num)`
#  - Write a function `login(username, password)`
#     - Correct → `"Login Successful"`
#     - Else → `"Invalid Credentials"`

# %%
# Question 1: Calculate Percentage

def calculate_percentage(obtained, total):
    return (obtained / total) * 100

print(calculate_percentage(450, 500))
# Out:
# 90.0

# %%
# Question 2: Calculate Salary

def calculate_salary(hours, rate):
    return hours * rate

print(calculate_salary(8, 500))
# Out:
# 4000

# %%
# Question 3: Calculate Bill

def calculate_bill(price, quantity):
    return price * quantity

print(calculate_bill(250, 4))
# Out:
# 1000

# %%
# Question 4: Check Vowel

def is_vowel(char):
    return char.lower() in "aeiou"

print(is_vowel("A"))
print(is_vowel("b"))
# Out:
# True
# False

# %%
# Question 5: Count Digits

def count_digits(num):
    return len(str(num))

print(count_digits(12345))
# Out:
# 5

# %%
# Question 6: Reverse Number
def reverse_number(num):
    return int(str(num)[::-1])

print(reverse_number(12345))
# Out:
# 54321

# %%
# Question 7: Login System

def login(username, password):
    if username == "admin" and password == "1234":
        return "Login Successful"
    else:
        return "Invalid Credentials"

print(login("admin", "1234"))
print(login("hamad", "1111"))
# Out:
# Login Successful
# Invalid Credentials

# %% [markdown]
# =========================== THE END ==============================
